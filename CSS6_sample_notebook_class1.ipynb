# %% [markdown]
# <a href="https://colab.research.google.com/github/Aarchi8824/computational-statistics-course-semester-6/blob/main/CSS6_sample_notebook_class1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import matplotlib.pyplot as plt

# %%
 ad_expense = [10, 20, 50, 41, 53]
 sales = [500, 750, 932, 1140, 1290]
 plt.plot(ad_expense, sales)
